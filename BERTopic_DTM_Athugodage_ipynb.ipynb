# %% [markdown]
# <a href="https://colab.research.google.com/github/Athugodage/RuLawSimplification/blob/main/BERTopic_DTM_Athugodage_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Athugodage/RuLawSimplification.git
# Out:
# Cloning into 'RuLawSimplification'...
# remote: Enumerating objects: 257, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 257 (delta 84), reused 115 (delta 55), pack-reused 76
# Receiving objects: 100% (257/257), 152.39 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %%
# !unzip '/content/RuLawSimplification/unfiltered_corpus.zip'
# Out:
# Archive:  /content/RuLawSimplification/unfiltered_corpus.zip
#   inflating: unfiltered_corpus.csv

# %%
import pandas as pd


df = pd.read_csv('unfiltered_corpus.csv')

# %%
df
# Out:
#                                      Название документа  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                  Ссылка  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                   Текст  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                          Комментарий РГ                Дата
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...      28 ноября 2022
# 1     Бессрочный запрет на профессию для адвокатов, ...      25 ноября 2022
# 2     Пленум Верховного суда России утвердил постано...      25 ноября 2022
# 3     На сладкую газировку с 1 июля 2023 года введут...      24 ноября 2022
# 4     Приостановленное в этом году бюджетное правило...      24 ноября 2022
# ...                                                 ...                 ...
# 2958  Производители жизненно необходимых и важнейших...  14 августа 2009 г.
# 2959  Правительство утвердило новые правила, как опл...  12 августа 2009 г.
# 2960  Частные охранники и детективы должны будут про...   7 августа 2009 г.
# 2961  В России усилят контроль за производством и об...   5 августа 2009 г.
# 2962  В этом году деятельность патентных поверенных ...  31 декабря 2008 г.
#
# [2963 rows x 5 columns]

# %% [markdown]
# # **Tutorial** - Dynamic Topic Modeling with Trump's Tweets
# (last updated 11-09-2022)
#
# In this tutorial we will be using Dynamic Topic Modeling with BERTopic to visualize how topics in Trump's Tweets have evolved over time. These topics will be visualized and thoroughly explored.
#
# ## Dynamic Topic Models
# Dynamic topic models can be used to analyze the evolution of topics of a collection of documents over time.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**
# For this tutorial, we will be needing to extract all Trump's Tweet from his @realDonalTrump account. We will be removing all retweet and focus on his original tweets.
#
# Moreover, since we are looking at his tweets over time, we will be saving all timestamps related to his tweets.

# %%
import re

df['Year'] = df['Дата'].apply(lambda x: re.search('\d{4}', x).group(0))

# %%
df
# Out:
#                                      Название документа  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                  Ссылка  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                   Текст  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                          Комментарий РГ                Дата  \
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...      28 ноября 2022
# 1     Бессрочный запрет на профессию для адвокатов, ...      25 ноября 2022
# 2     Пленум Верховного суда России утвердил постано...      25 ноября 2022
# 3     На сладкую газировку с 1 июля 2023 года введут...      24 ноября 2022
# 4     Приостановленное в этом году бюджетное правило...      24 ноября 2022
# ...                                                 ...                 ...
# 2958  Производители жизненно необходимых и важнейших...  14 августа 2009 г.
# 2959  Правительство утвердило новые правила, как опл...  12 августа 2009 г.
# 2960  Частные охранники и детективы должны будут про...   7 августа 2009 г.
# 2961  В России усилят контроль за производством и об...   5 августа 2009 г.
# 2962  В этом году деятельность патентных поверенных ...  31 декабря 2008 г.
#
#       Year
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ...    ...
# 2958  2009
# 2959  2009
# 2960  2009
# 2961  2009
# 2962  2008
#
# [2963 rows x 6 columns]

# %%
timestamps = df['Year'].to_list()

# %%
import re
import pandas as pd
from datetime import datetime


text = df['Текст'].to_list()

# %%
from tqdm import tqdm

docs = []

for t in tqdm(text):    
    docs.append(re.sub('[\d|A-z]*', '', t.strip()))
# Out:
# 100%|██████████| 2963/2963 [00:15<00:00, 191.78it/s]

# %%
docs[0]
# Out:
# '. Внести в Указ временно исполняющего обязанности Главы Донецкой Народной Республики от  ноября  г. №  изменение, изложив пункт  в следующей редакции:  ". Уволить с военной службы граждан, призванных на военную службу по мобилизации, получавших на момент их призыва образование соответствующего уровня впервые, обучавшихся по очной и очно-заочной формам обучения:  .. В образовательных и научных организациях по имеющим государственную аккредитацию образовательным программам среднего профессионального и высшего образования (в том числе программам ординатуры и программам ассистентуры-стажировки).  .. В образовательных и научных организациях по программам подготовки научных и научно-педагогических кадров в аспирантуре.".  . Настоящий Указ вступает в силу со дня его подписания.  Врио Главы Донецкой Народной Республики Д.В.Пушилин'

# %%
docs[-1]
# Out:
# 'Принят Государственной Думой  декабря  года  Одобрен Советом Федерации  декабря  года  Статья . Предмет регулирования  . Настоящий Федеральный закон в соответствии с Гражданским кодексом Российской Федерации регулирует отношения, связанные с деятельностью на территории Российской Федерации патентных поверенных, определяет требования к патентным поверенным, устанавливает порядок их аттестации и регистрации, а также определяет права, обязанности и ответственность патентных поверенных.  . Патентный поверенный осуществляет ведение дел с федеральным органом исполнительной власти по интеллектуальной собственности по поручению заявителей, правообладателей и иных заинтересованных граждан и юридических лиц, постоянно проживающих (для граждан) или имеющих место нахождения (для юридических лиц) в Российской Федерации и за ее пределами, если международным договором Российской Федерации или законодательством Российской Федерации не предусмотрено иное.  Статья . Требования, предъявляемые к патентному поверенному  . Патентными поверенными признаются граждане, получившие в установленном настоящим Федеральным законом порядке статус патентного поверенного и осуществляющие деятельность, связанную с правовой охраной результатов интеллектуальной деятельности и средств индивидуализации, защитой интеллектуальных прав, приобретением исключительных прав на результаты интеллектуальной деятельности и средства индивидуализации, распоряжением такими правами (далее - деятельность патентного поверенного).  . В качестве патентного поверенного может быть аттестован и зарегистрирован гражданин Российской Федерации, который:  ) достиг возраста  лет;  ) постоянно проживает на территории Российской Федерации;  ) имеет высшее образование;  ) имеет не менее чем четырехлетний опыт работы в сфере деятельности патентного поверенного в соответствии со специализацией, применительно к которой гражданин выражает желание быть аттестованным и зарегистрированным в качестве патентного поверенного.  . Не могут быть аттестованы в качестве патентных поверенных:  ) граждане, признанные в установленном законодательством Российской Федерации порядке недееспособными или ограниченно дееспособными;  ) граждане, деятельность которых в качестве патентных поверенных приостановлена решением суда на определенный срок, до его истечения и граждане, которые исключены из Реестра патентных поверенных Российской Федерации (далее - Реестр), в порядке, предусмотренном статьей  настоящего Федерального закона.  . Не могут быть зарегистрированы в качестве патентных поверенных:  ) государственные служащие, лица, замещающие государственные должности Российской Федерации, государственные должности субъектов Российской Федерации, муниципальные должности, и муниципальные служащие;  ) работники организаций, находящихся в ведении федерального органа исполнительной власти по интеллектуальной собственности;  ) граждане, признанные в установленном законодательством Российской Федерации порядке недееспособными или ограниченно дееспособными.  Статья . Формы осуществления деятельности патентных поверенных  . Патентный поверенный вправе осуществлять свою профессиональную деятельность самостоятельно, занимаясь частной практикой, а также на основании трудового договора между патентным поверенным и работодателем (юридическим лицом).  . Работодатель патентного поверенного, заключивший с заявителем, правообладателем или иным заинтересованным лицом гражданско-правовой договор, включающий в себя условия о выполнении работ (оказании услуг), относящихся к деятельности патентного поверенного, обязан:  ) обеспечивать надлежащее исполнение патентным поверенным, с которым у него заключен трудовой договор, соответствующего поручения и в случае его ненадлежащего исполнения применять к патентному поверенному меры дисциплинарной ответственности в соответствии с трудовым законодательством;  ) обеспечивать сохранность документов, получаемых от поручителя, заказчика, иных лиц в ходе исполнения гражданско-правового договора;  ) сообщ ...

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all tweets. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those tweets.

# %%
stopwords = open('/content/RuLawSimplification/stopwords/russian')

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(stop_words=stopwords)

# %% [markdown]
# Min_topic_size = 3

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=3, 
                       verbose=True, 
                       language='russian', 
                       top_n_words = 10,
                       n_gram_range=(3, 7),
                       vectorizer_model=vectorizer_model)

# %%
topics, _ = topic_model.fit_transform(text)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]
# 2022-12-16 15:49:55,900 - BERTopic - Transformed documents to Embeddings
# 2022-12-16 15:50:10,038 - BERTopic - Reduced dimensionality
# 2022-12-16 15:50:10,261 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                            Name
# 0     -1    446    -1_наследия_культурного_российской_федерации
# 1      0     46                0_цвета_кооператива_ордена_темно
# 2      1     37  1_диссертационного_совета_обучение_грузобагажа
# 3      2     36   2_финансовых_контракта_кредитного_кооператива
# 4      3     35                                3_рф_гк_апк_суда
# 5      4     34    4_волгоградской_области_коронавирусной_covid
# 6      5     33            5_коронавирусной_инфекции_2020_новой
# 7      6     31            6_субсидии_настоящих_кредитам_правил
# 8      7     27                  7_мвд_услуги_россии_регламенту
# 9      8     25  8_вступительных_испытаний_аудируемого_обучения

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(4)
# Out:
# [('волгоградской', 0.02432525373579254),
#  ('области', 0.020114781510556894),
#  ('коронавирусной', 0.01811171493308765),
#  ('covid', 0.01798864849201044),
#  ('инфекции', 0.016442976774185304),
#  ('новой', 0.015122731398608412),
#  ('обеспечить', 0.01491807877131643),
#  ('мурманской', 0.013154008656547141),
#  ('нижегородской', 0.01127646636324033),
#  ('чрезвычайных', 0.011261898863056742)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map. This allows us to judge visually whether the basic topics are sufficient before proceeding to creating the topics over time.

# %%
fig = topic_model.visualize_topics(); fig

# %% [markdown]
# ## Topics over Time
# Before we start with the Dynamic Topic Modeling step, it is important that you are satisfied with the topics that were created previously. We are going to be using those specific topics as a base for Dynamic Topic Modeling.
#
# Thus, this step will essentially show you how the topics that were defined previously have evolved over time.

# %% [markdown]
# There are a few important parameters that you should take note of, namely:
#
# * `docs`
#   * These are the tweets that we are using
# * `timestamps`
#   * The timestamp of each tweet/document
# * `global_tuning`
#   * Whether to average the topic representation of a topic at time *t* with its global topic representation
# * `evolution_tuning`
#   * Whether to average the topic representation of a topic at time *t* with the topic representation of that topic at time *t-1*
# * `nr_bins`
#   * The number of bins to put our timestamps into. It is computationally inefficient to extract the topics at thousands of different timestamps. Therefore, it is advised to keep this value below 20.

# %%
topics_over_time = topic_model.topics_over_time(docs=text, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 15it [00:14,  1.02it/s]

# %% [markdown]
# ## Visualize Topics over Time
# After having created our `topics_over_time`, we will have to visualize those topics as accessing them becomes a bit more difficult with the added temporal dimension.
#
# To do so, we are going to visualize the distribution of topics over time based on their frequency. Doing so allows us to see how the topics have evolved over time. Make sure to hover over any point to see how the topic representation at time *t* differs from the global topic representation.

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb611f37-414c-4f84-8058-d6be32de7eaa" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb611f37-414c-4f84-8058-d6be32de7eaa")) {                    Plotly.newPlot(                        "bb611f37-414c-4f84-8058-d6be32de7eaa",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u0431\u0430\u0434, \u043a\u0430\u043d\u0434\u0438\u0434\u0430\u0442\u0443\u0440\u0430\u0445, \u0446\u0432\u0435\u0442\u0430, \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u0430, \u0446\u0435\u043d\u0442\u0440\u0430","<b>Topic 0</b><br>Words: \u043e\u0440\u0434\u0435\u043d\u0430, \u043c\u043c, \u0437\u0430\u0441\u043b\u0443\u0436\u0435\u043d\u043d\u044b\u0439, \u0437\u0430\u0441\u043b\u0443\u0433\u0438, \u0446\u0432\u0435\u0442\u0430","<b>Topic 0</b><br>Words: \u0434\u0440\u0443\u0436\u0438\u043d, \u0434\u0440\u0443\u0436\u0438\u043d\u044b, \u043b\u0438\u0446\u0435\u043d\u0437\u0438\u0438, \u0446\u0432\u0435\u0442\u0430, \u0433\u0440\u0430\u043d\u0438\u0446\u044b","<b>Topic 0</b><br>Words: \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430, \u0443\u0438\u0441, \u0446\u0432\u0441\u043d\u043f, \u0447\u043b\u0435\u043d\u043e\u0432, \u0446\u0432\u0435\u0442\u0430","<b>Topic 0</b><br>Words: \u0446\u0432\u0435\u0442\u0430, \u0442\u0435\u043c\u043d\u043e, \u0441\u0438\u043d\u0435\u0433\u043e, \u0447\u0435\u0440\u043d\u043e\u0433\u043e, \u043e\u0434\u0435\u0436\u0434\u044b","<b>Topic 0</b><br>Words: \u043d\u0430\u0443\u0447\u043d\u043e, \u043d\u0430\u0447\u0430\u043b\u044c\u043d\u0438\u043a, \u0437\u0430\u043c\u0435\u0441\u0442\u0438\u0442\u0435\u043b\u044c, \u0438\u0441\u043f\u044b\u0442\u0430\u0442\u0435\u043b\u044c\u043d\u043e\u0433\u043e, \u043d\u0430\u0447\u0430\u043b\u044c\u043d\u0438\u043a\u0430","<b>Topic 0</b><br>Words: \u0430\u043c\u043d\u0438\u0441\u0442\u0438\u0438, \u043f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u044f, \u043e\u0441\u0443\u0436\u0434\u0435\u043d\u043d\u044b\u0445, \u0433\u043e\u0441\u0442\u0438\u043d\u0438\u0447\u043d\u044b\u0445, \u0446\u0432\u0435\u0442\u0430","<b>Topic 0</b><br>Words: \u043a\u043e\u043c\u0438\u0441\u0441\u0438\u0438, \u0443\u0447\u0435\u043d\u044b\u0445, \u0441\u0442\u0435\u043f\u0435\u043d\u0435\u0439, \u0441\u043e\u0432\u0435\u0442\u043e\u0432, \u043f\u0440\u0435\u0437\u0438\u0434\u0438\u0443\u043c\u0430","<b>Topic 0</b><br>Words: \u043a\u0430\u0434\u0440\u043e\u0432\u044b\u0439, \u0440\u0435\u0437\u0435\u0440\u0432, \u0433\u0440\u0430\u0436\u0434\u0430\u043d\u0441\u043a\u043e\u0439, \u0441\u043b\u0443\u0436\u0431\u044b, \u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u043e\u0439","<b>Topic 0</b><br>Words: \u0430\u043b\u0442\u0430\u0439\u0441\u043a\u043e\u0433\u043e, \u043a\u0440\u0430\u044f, \u0442\u043e\u043c\u0435\u043d\u043a\u043e, \u0437\u0441, \u0441\u0444\u043e\u0440\u043c\u0438\u0440\u043e\u0432\u0430\u043d\u043d\u044b\u043c","<b>Topic 0</b><br>Words: \u043e\u0437, \u0442\u044e\u043c\u0435\u043d\u0441\u043a\u043e\u0439, \u0446\u0432\u0435\u0442\u0430, 03, 2020","<b>Topic 0</b><br>Words: 2021, 2020, \u043e\u0442, 04, \u0435\u0434\u0438\u043d\u043e\u0432\u0440\u0435\u043c\u0435\u043d\u043d\u0430\u044f"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_\u0446\u0432\u0435\u0442\u0430_\u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430_\u043e\u0440\u0434\u0435\u043d\u0430_\u0442\u0435\u043c\u043d\u043e","x":["2008-09-12T16:48:00","2009-05-26T09:36:00","2010-10-19T19:12:00","2011-07-02T12:00:00","2012-11-24T21:36:00","2013-08-07T14:24:00","2014-04-20T07:12:00","2015-09-13T16:48:00","2016-05-26T09:36:00","2017-10-19T19:12:00","2019-11-25T21:36:00","2020-08-07T14:24:00"],"y":[5,5,7,6,6,1,3,2,1,1,2,7],"type":"scat ...

# %% [markdown]
# Min_topic_size=5

# %%
from bertopic import BERTopic
topic_model_1 = BERTopic(min_topic_size=5, 
                       verbose=True, 
                       language='russian', 
                       top_n_words = 10,
                       n_gram_range=(5, 8),
                       vectorizer_model=vectorizer_model)

# %%
topics, _ = topic_model_1.fit_transform(text)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]
# 2022-12-16 16:29:02,887 - BERTopic - Transformed documents to Embeddings
# 2022-12-16 16:29:17,674 - BERTopic - Reduced dimensionality
# 2022-12-16 16:29:17,842 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model_1.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                               Name
# 0     -1    502  -1_транспортной_безопасности_федерации_российской
# 1      0     88           0_или_таможенного_исполнительной_товаров
# 2      1     57                      1_цифры_цифрами_ст_налогового
# 3      2     49                       2_кандидатов_тысяч_ст_против
# 4      3     47               3_2020_коронавирусной_инфекции_новой
# 5      4     45                   4_цвета_кооператива_ордена_темно
# 6      5     39                        5_мвд_внутренних_дел_россии
# 7      6     39  6_транспортного_средства_метрополитена_транспо...
# 8      7     36       7_области_волгоградской_коронавирусной_covid
# 9      8     36              8_диссертационного_совета_обучение_ст

# %%
topic_model_1.get_topic(4)
# Out:
# [('цвета', 0.031803015294091304),
#  ('кооператива', 0.02060500426610573),
#  ('ордена', 0.017425862593434614),
#  ('темно', 0.015557481666295267),
#  ('синего', 0.01552269279903231),
#  ('мм', 0.013980558112498823),
#  ('черного', 0.012123575636567085),
#  ('заслуженный', 0.011965772778991265),
#  ('заслуги', 0.011255586612232414),
#  ('одежды', 0.011166600884369195)]

# %%
fig = topic_model_1.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f85ac61a-cac4-4be9-9809-9d8866b9abd8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f85ac61a-cac4-4be9-9809-9d8866b9abd8")) {                    Plotly.newPlot(                        "f85ac61a-cac4-4be9-9809-9d8866b9abd8",                        [{"customdata":[[0,"\u0438\u043b\u0438 | \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0433\u043e | \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 | \u0442\u043e\u0432\u0430\u0440\u043e\u0432 | \u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u043c",88],[1,"\u0446\u0438\u0444\u0440\u044b | \u0446\u0438\u0444\u0440\u0430\u043c\u0438 | \u0441\u0442 | \u043d\u0430\u043b\u043e\u0433\u043e\u0432\u043e\u0433\u043e | \u0441\u044b\u0440\u044c\u044f",57],[2,"\u043a\u0430\u043d\u0434\u0438\u0434\u0430\u0442\u043e\u0432 | \u0442\u044b\u0441\u044f\u0447 | \u0441\u0442 | \u043f\u0440\u043e\u0442\u0438\u0432 | \u0430\u0442\u0440\u0438\u0431\u0443\u0442\u0438\u043a\u0438",49],[3,"2020 | \u043a\u043e\u0440\u043e\u043d\u0430\u0432\u0438\u0440\u0443\u0441\u043d\u043e\u0439 | \u0438\u043d\u0444\u0435\u043a\u0446\u0438\u0438 | \u043d\u043e\u0432\u043e\u0439 | covid",47],[4,"\u0446\u0432\u0435\u0442\u0430 | \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430 | \u043e\u0440\u0434\u0435\u043d\u0430 | \u0442\u0435\u043c\u043d\u043e | \u0441\u0438\u043d\u0435\u0433\u043e",45],[5,"\u043c\u0432\u0434 | \u0432\u043d\u0443\u0442\u0440\u0435\u043d\u043d\u0438\u0445 | \u0434\u0435\u043b | \u0440\u043e\u0441\u0441\u0438\u0438 | \u043f\u043e\u043b\u0438\u0446\u0438\u0438",39],[6,"\u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u043d\u043e\u0433\u043e | \u0441\u0440\u0435\u0434\u0441\u0442\u0432\u0430 | \u043c\u0435\u0442\u0440\u043e\u043f\u043e\u043b\u0438\u0442\u0435\u043d\u0430 | \u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u043d\u043e\u0439 | \u0434\u0432\u0438\u0436\u0435\u043d\u0438\u044f",39],[7,"\u043e\u0431\u043b\u0430\u0441\u0442\u0438 | \u0432\u043e\u043b\u0433\u043e\u0433\u0440\u0430\u0434\u0441\u043a\u043e\u0439 | \u043a\u043e\u0440\u043e\u043d\u0430\u0432\u0438\u0440\u0443\u0441\u043d\u043e\u0439 | covid | \u0438\u043d\u0444\u0435\u043a\u0446\u0438\u0438",36],[8,"\u0434\u0438\u0441\u0441\u0435\u0440\u0442\u0430\u0446\u0438\u043e\u043d\u043d\u043e\u0433\u043e | \u0441\u043e\u0432\u0435\u0442\u0430 | \u043e\u0431\u0443\u0447\u0435\u043d\u0438\u0435 | \u0441\u0442 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0430\u043c",36],[9,"\u043f\u0435\u043d\u0441\u0438\u0438 | \u0440\u0435\u043d\u043e\u0432\u0430\u0446\u0438\u0438 | \u0437\u0430\u043d\u044f\u0442\u043e\u0441\u0442\u0438 | \u0441\u0442 | \u0441\u0442\u0440\u0430\u0445\u043e\u0432\u043e\u0439",31],[10,"\u043c\u0432\u0434 | \u0443\u0441\u043b\u0443\u0433\u0438 | \u0440\u043e\u0441\u0441\u0438\u0438 | \u043f\u0440\u0435\u0434\u043e\u0441\u0442\u0430\u0432\u043b\u0435\u043d\u0438\u044f | \u0433\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439",29],[11,"\u043f\u0435\u0440\u0435\u0432\u043e\u0437\u043e\u043a | \u0440\u0435\u0433\u0443\u043b\u044f\u0440\u043d\u044b\u0445 | \u043e\u0441\u043c\u043e\u0442\u0440\u0430 | \u043c\u0430\u0440\u0448\u0440\u0443\u0442\u0430 | \u043c\u0430\u0440\u0448\u0440\u0443\u0442\u0443",29],[12,"\u043d\u0430\u043b\u043e\u0433\u043e\u0432\u043e\u0433\u043e | \u043d\u0430\u043b\u043e\u0433\u0430 | \u043a\u043e\u0434\u0435\u043a\u0441\u0430 | \u0438\u043d\u043e\u0441\u0442\u0440\u0430\u043d\u043d\u043e\u0439 | \u043f\u0443\u043d\u043a\u0442\u0430",28],[13,"\u0441\u0447\u0435\u0442\u0430 | \u0441\u0447\u0435\u0442\u043e\u0432 | \u0440\u0430\u0441\u0447\u0435\u0442\u044b | \u0434\u0435\u0431\u0435\u0442\u0443 ...

# %%
topics_over_time = topic_model_1.topics_over_time(docs=text, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-d79eb605b102> in <module>
# ----> 1 topics_over_time = topic_model_1.topics_over_time(docs=text,
#       2                                                 timestamps=timestamps,
#       3                                                 global_tuning=True,
#       4                                                 evolution_tuning=True,
#       5                                                 nr_bins=20)
#
# /usr/local/lib/python3.8/dist-packages/bertopic/_bertopic.py in topics_over_time(self, docs, timestamps, nr_bins, datetime_format, evolution_tuning, global_tuning)
#     648         ```
#     649         """
# --> 650         check_is_fitted(self)
#     651         check_documents_type(docs)
#     652         documents = pd.DataFrame({"Document": docs, "Topic": self.topics_, "Timestamps": timestamps})
#
# /usr/local/lib/python3.8/dist-packages/bertopic/_utils.py in check_is_fitted(topic_model)
#      68
#      69     if topic_model.topics_ is None:
# ---> 70         raise ValueError(msg % {'name': type(topic_model).__name__})
#      71
#      72
#
# ValueError: This BERTopic instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
topic_model_1.visualize_topics_over_time(topics_over_time, top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="103f6994-8308-40ed-868b-6efcd3fa25ca" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("103f6994-8308-40ed-868b-6efcd3fa25ca")) {                    Plotly.newPlot(                        "103f6994-8308-40ed-868b-6efcd3fa25ca",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u043f\u043e\u0432\u0435\u0440\u0435\u043d\u043d\u043e\u0433\u043e, \u043f\u0430\u0442\u0435\u043d\u0442\u043d\u043e\u0433\u043e, \u043f\u043e\u0432\u0435\u0440\u0435\u043d\u043d\u044b\u0445, \u043f\u0430\u0442\u0435\u043d\u0442\u043d\u044b\u0445, \u0438\u043d\u0442\u0435\u043b\u043b\u0435\u043a\u0442\u0443\u0430\u043b\u044c\u043d\u043e\u0439","<b>Topic 0</b><br>Words: \u043a\u0440\u0435\u0434\u0438\u0442\u043d\u043e\u0433\u043e, \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430, \u044d\u043d\u0435\u0440\u0433\u0435\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0439, \u044d\u0444\u0444\u0435\u043a\u0442\u0438\u0432\u043d\u043e\u0441\u0442\u0438, \u0432\u043e\u0437\u0434\u0443\u0448\u043d\u044b\u0435","<b>Topic 0</b><br>Words: \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0433\u043e, \u0442\u043e\u0432\u0430\u0440\u043e\u0432, \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u044b\u0445, \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0439, \u043b\u0435\u043a\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0433\u043e","<b>Topic 0</b><br>Words: \u043f\u043b\u0430\u0442\u0435\u0436\u043d\u043e\u0439, \u0440\u0430\u0434\u0438\u043e\u0430\u043a\u0442\u0438\u0432\u043d\u044b\u0445, \u043e\u0442\u0445\u043e\u0434\u043e\u0432, \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u0441\u0438\u0441\u0442\u0435\u043c\u044b","<b>Topic 0</b><br>Words: \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u043d\u0438\u044f, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u0443\u044e, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u044b\u0445, \u043e\u0431\u0443\u0447\u0430\u044e\u0449\u0438\u0445\u0441\u044f","<b>Topic 0</b><br>Words: \u043a\u043e\u043d\u0442\u0440\u0430\u043a\u0442\u0430, \u0437\u0430\u043a\u0443\u043f\u043e\u043a, \u0443\u0447\u0430\u0441\u0442\u0438\u0435, \u0437\u0430\u043a\u0443\u043f\u043a\u0438, \u0430\u0443\u043a\u0446\u0438\u043e\u043d\u0435","<b>Topic 0</b><br>Words: \u0441\u0442\u0440\u0430\u0442\u0435\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0433\u043e, \u043f\u043b\u0430\u043d\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f, \u0441\u043e\u0446\u0438\u0430\u043b\u044c\u043d\u043e, \u0440\u0430\u0437\u0432\u0438\u0442\u0438\u044f, \u044d\u043a\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u043e\u0433\u043e","<b>Topic 0</b><br>Words: \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u0438, \u0430\u0434\u043c\u0438\u043d\u0438\u0441\u0442\u0440\u0430\u0442\u0438\u0432\u043d\u043e\u0433\u043e, \u0441\u0443\u0434\u0430, \u0438\u043b\u0438, \u0441\u0443\u0434","<b>Topic 0</b><br>Words: \u0442\u043e\u0432\u0430\u0440\u0438\u0449\u0435\u0441\u0442\u0432\u0430, \u0441\u0430\u0434\u043e\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u043e\u0433\u043e\u0440\u043e\u0434\u043d\u0438\u0447\u0435\u0441\u0442\u0432\u0430, \u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u0430, \u0437\u0430\u0441\u0442\u0440\u043e\u0439\u0449\u0438\u043a\u0430","<b>Topic 0</b><br>Words: \u0443\u0433\u043e\u043b\u043e\u0432\u043d\u043e, \u043e\u0431\u0449\u0435\u0441\u0442\u0432\u0430, \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u0436\u0438\u ...

# %% [markdown]
# min_topic_size=10
# n_gram_range 3-5
# top_n_words = 15

# %%
from bertopic import BERTopic
topic_model_10 = BERTopic(min_topic_size=10, 
                       verbose=True, 
                       language='russian', 
                       top_n_words = 15,
                       n_gram_range=(3, 5))

# %%
topics, _ = topic_model_10.fit_transform(text)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]
# 2022-12-16 16:32:49,026 - BERTopic - Transformed documents to Embeddings
# 2022-12-16 16:33:04,148 - BERTopic - Reduced dimensionality
# 2022-12-16 16:33:04,274 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model_10.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                               Name
# 0     -1    599  -1_субъекта российской федерации_законодательс...
# 1      0    171  0_настоящего федерального закона_объектов куль...
# 2      1    121  1_на срок до_свободы на срок_свободы на срок д...
# 3      2     99  2_тысяч рублей на_наложение административного ...
# 4      3     97  3_правительства российской федерации_правитель...
# 5      4     87  4_настоящего федерального закона_настоящим фед...
# 6      5     61  5_социально экономического исключить_слово соц...
# 7      6     58  6_000 заменить цифрами_налогового кодекса росс...
# 8      7     50  7_счетов аналитического учета_соответствующих ...
# 9      8     50  8_на постоянное проживание_на территории иност...

# %%
topic_model_10.get_topic(4)
# Out:
# [('настоящего федерального закона', 0.003931830291768325),
#  ('настоящим федеральным законом', 0.002336157810575059),
#  ('законодательством российской федерации', 0.0021411647470298877),
#  ('органом исполнительной власти', 0.0017976198540410244),
#  ('федеральным органом исполнительной власти', 0.001767062017948639),
#  ('федеральным органом исполнительной', 0.0017668397258272632),
#  ('части настоящей статьи', 0.0017177073990185753),
#  ('правительством российской федерации', 0.0015708650657216404),
#  ('субъектов российской федерации', 0.0015070062475504168),
#  ('субъекта российской федерации', 0.0012723529435434428),
#  ('органах принудительного исполнения', 0.0011972942122428346),
#  ('соответствии законодательством российской федерации',
#   0.0011410049842613278),
#  ('соответствии законодательством российской', 0.0011399846289156018),
#  ('уголовно исполнительной системе', 0.0010721996482279507),
#  ('законодательства российской федерации', 0.0010523507924943137)]

# %%
fig = topic_model_10.visualize_topics(); fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-be970cacf711> in <module>
# ----> 1 fig = topic_model_10.visualize_topics(); fig
#
# NameError: name 'topic_model_10' is not defined

# %%
topics_over_time = topic_model_10.topics_over_time(docs=text, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)

# %%
topic_model_1.visualize_topics_over_time(topics_over_time, top_n_topics=20)
