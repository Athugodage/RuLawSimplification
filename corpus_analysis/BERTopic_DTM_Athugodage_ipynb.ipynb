# %% [markdown]
# <a href="https://colab.research.google.com/github/Athugodage/RuLawSimplification/blob/main/corpus_analysis/BERTopic_DTM_Athugodage_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Athugodage/RuLawSimplification.git
# Out:
# Cloning into 'RuLawSimplification'...
# remote: Enumerating objects: 275, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 275 (delta 2), reused 1 (delta 1), pack-reused 265
# Receiving objects: 100% (275/275), 156.67 MiB | 16.64 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# !unzip '/content/RuLawSimplification/unfiltered_corpus.zip'
# Out:
# Archive:  /content/RuLawSimplification/unfiltered_corpus.zip
#   inflating: unfiltered_corpus.csv

# %%
import pandas as pd


df = pd.read_csv('unfiltered_corpus.csv')

# %%
df
# Out:
#                                      Название документа  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                  Ссылка  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                   Текст  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                          Комментарий РГ                Дата
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...      28 ноября 2022
# 1     Бессрочный запрет на профессию для адвокатов, ...      25 ноября 2022
# 2     Пленум Верховного суда России утвердил постано...      25 ноября 2022
# 3     На сладкую газировку с 1 июля 2023 года введут...      24 ноября 2022
# 4     Приостановленное в этом году бюджетное правило...      24 ноября 2022
# ...                                                 ...                 ...
# 2958  Производители жизненно необходимых и важнейших...  14 августа 2009 г.
# 2959  Правительство утвердило новые правила, как опл...  12 августа 2009 г.
# 2960  Частные охранники и детективы должны будут про...   7 августа 2009 г.
# 2961  В России усилят контроль за производством и об...   5 августа 2009 г.
# 2962  В этом году деятельность патентных поверенных ...  31 декабря 2008 г.
#
# [2963 rows x 5 columns]

# %% [markdown]
# # **Tutorial** - Dynamic Topic Modeling with Trump's Tweets
# (last updated 11-09-2022)
#
# In this tutorial we will be using Dynamic Topic Modeling with BERTopic to visualize how topics in Trump's Tweets have evolved over time. These topics will be visualized and thoroughly explored.
#
# ## Dynamic Topic Models
# Dynamic topic models can be used to analyze the evolution of topics of a collection of documents over time.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**
# For this tutorial, we will be needing to extract all Trump's Tweet from his @realDonalTrump account. We will be removing all retweet and focus on his original tweets.
#
# Moreover, since we are looking at his tweets over time, we will be saving all timestamps related to his tweets.

# %%
import re

df['Year'] = df['Дата'].apply(lambda x: re.search('\d{4}', x).group(0))

# %%
df
# Out:
#                                      Название документа  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                  Ссылка  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                   Текст  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                          Комментарий РГ                Дата  \
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...      28 ноября 2022
# 1     Бессрочный запрет на профессию для адвокатов, ...      25 ноября 2022
# 2     Пленум Верховного суда России утвердил постано...      25 ноября 2022
# 3     На сладкую газировку с 1 июля 2023 года введут...      24 ноября 2022
# 4     Приостановленное в этом году бюджетное правило...      24 ноября 2022
# ...                                                 ...                 ...
# 2958  Производители жизненно необходимых и важнейших...  14 августа 2009 г.
# 2959  Правительство утвердило новые правила, как опл...  12 августа 2009 г.
# 2960  Частные охранники и детективы должны будут про...   7 августа 2009 г.
# 2961  В России усилят контроль за производством и об...   5 августа 2009 г.
# 2962  В этом году деятельность патентных поверенных ...  31 декабря 2008 г.
#
#       Year
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ...    ...
# 2958  2009
# 2959  2009
# 2960  2009
# 2961  2009
# 2962  2008
#
# [2963 rows x 6 columns]

# %%
timestamps = df['Year'].to_list()

# %%
import re
import pandas as pd
from datetime import datetime


text = df['Текст'].to_list()

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all tweets. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those tweets.

# %%
stopwords = open('/content/RuLawSimplification/stopwords/russian')

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(stop_words=stopwords)

# %% [markdown]
# Min_topic_size = 3

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=3, 
                       verbose=True, 
                       language='russian', 
                       top_n_words = 10,
                       n_gram_range=(3, 7),
                       vectorizer_model=vectorizer_model)

# %%
topics, _ = topic_model.fit_transform(text)
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]
# 2022-12-16 16:57:25,459 - BERTopic - Transformed documents to Embeddings
# 2022-12-16 16:57:45,168 - BERTopic - Reduced dimensionality
# 2022-12-16 16:57:45,397 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                              Name
# 0     -1    454                     -1_наследия_культурного_по_ст
# 1      0     88  0_таможенного_товаров_исполнительной_федеральным
# 2      1     39           1_диссертационного_строка_строке_ценных
# 3      2     37      2_волгоградской_области_коронавирусной_covid
# 4      3     35                                  3_рф_гк_апк_суда
# 5      4     33   4_транспортного_метрополитена_средства_движения
# 6      5     32                  5_цвета_кооператива_ордена_темно
# 7      6     26    6_вступительных_испытаний_аудируемого_обучения
# 8      7     24                    7_мвд_услуги_россии_регламенту
# 9      8     22             8_реновации_отечества_погибших_пенсии

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(4)
# Out:
# [('транспортного', 0.02552910973709635),
#  ('метрополитена', 0.01727272202129975),
#  ('средства', 0.017143018345292357),
#  ('движения', 0.012947951739692641),
#  ('транспортной', 0.012132797073715097),
#  ('дорожного', 0.011113015110568298),
#  ('дорожно', 0.010493275566572204),
#  ('безопасности', 0.009995625798187927),
#  ('транспортных', 0.009930492870964317),
#  ('владельца', 0.009382561252599623)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map. This allows us to judge visually whether the basic topics are sufficient before proceeding to creating the topics over time.

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f37aa125-d13a-4073-a4b1-96e09096e952" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f37aa125-d13a-4073-a4b1-96e09096e952")) {                    Plotly.newPlot(                        "f37aa125-d13a-4073-a4b1-96e09096e952",                        [{"customdata":[[0,"\u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0433\u043e | \u0442\u043e\u0432\u0430\u0440\u043e\u0432 | \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 | \u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u043c | \u0432\u043b\u0430\u0441\u0442\u0438",88],[1,"\u0434\u0438\u0441\u0441\u0435\u0440\u0442\u0430\u0446\u0438\u043e\u043d\u043d\u043e\u0433\u043e | \u0441\u0442\u0440\u043e\u043a\u0430 | \u0441\u0442\u0440\u043e\u043a\u0435 | \u0446\u0435\u043d\u043d\u044b\u0445 | \u0431\u0443\u043c\u0430\u0433",39],[2,"\u0432\u043e\u043b\u0433\u043e\u0433\u0440\u0430\u0434\u0441\u043a\u043e\u0439 | \u043e\u0431\u043b\u0430\u0441\u0442\u0438 | \u043a\u043e\u0440\u043e\u043d\u0430\u0432\u0438\u0440\u0443\u0441\u043d\u043e\u0439 | covid | \u0438\u043d\u0444\u0435\u043a\u0446\u0438\u0438",37],[3,"\u0440\u0444 | \u0433\u043a | \u0430\u043f\u043a | \u0441\u0443\u0434\u0430 | \u043a\u0430\u0441",35],[4,"\u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u043d\u043e\u0433\u043e | \u043c\u0435\u0442\u0440\u043e\u043f\u043e\u043b\u0438\u0442\u0435\u043d\u0430 | \u0441\u0440\u0435\u0434\u0441\u0442\u0432\u0430 | \u0434\u0432\u0438\u0436\u0435\u043d\u0438\u044f | \u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u043d\u043e\u0439",33],[5,"\u0446\u0432\u0435\u0442\u0430 | \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430 | \u043e\u0440\u0434\u0435\u043d\u0430 | \u0442\u0435\u043c\u043d\u043e | \u0441\u0438\u043d\u0435\u0433\u043e",32],[6,"\u0432\u0441\u0442\u0443\u043f\u0438\u0442\u0435\u043b\u044c\u043d\u044b\u0445 | \u0438\u0441\u043f\u044b\u0442\u0430\u043d\u0438\u0439 | \u0430\u0443\u0434\u0438\u0440\u0443\u0435\u043c\u043e\u0433\u043e | \u043e\u0431\u0443\u0447\u0435\u043d\u0438\u044f | \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u043d\u0438\u0438",26],[7,"\u043c\u0432\u0434 | \u0443\u0441\u043b\u0443\u0433\u0438 | \u0440\u043e\u0441\u0441\u0438\u0438 | \u0440\u0435\u0433\u043b\u0430\u043c\u0435\u043d\u0442\u0443 | \u043e\u0440\u0443\u0436\u0438\u044f",24],[8,"\u0440\u0435\u043d\u043e\u0432\u0430\u0446\u0438\u0438 | \u043e\u0442\u0435\u0447\u0435\u0441\u0442\u0432\u0430 | \u043f\u043e\u0433\u0438\u0431\u0448\u0438\u0445 | \u043f\u0435\u043d\u0441\u0438\u0438 | \u0431\u0435\u0437\u0440\u0430\u0431\u043e\u0442\u0438\u0446\u0435",22],[9,"\u0441\u0432\u043e\u0431\u043e\u0434\u044b | \u043b\u0435\u0442 | \u043e\u0433\u0440\u0430\u043d\u0438\u0447\u0435\u043d\u0438\u0435\u043c | \u0441\u0440\u043e\u043a | \u0442\u0430\u043a\u043e\u0432\u043e\u0433\u043e",21],[10,"\u043c\u0432\u0434 | \u0432\u043d\u0443\u0442\u0440\u0435\u043d\u043d\u0438\u0445 | \u0434\u0435\u043b | \u043f\u043e\u043b\u0438\u0446\u0438\u0438 | \u0440\u043e\u0441\u0441\u0438\u0438",21],[11,"\u0443\u043c | \u043c\u043e\u0441\u043a\u0432\u044b | 2020 | \u043f\u0430\u0440\u043a | \u043c\u044d\u0440\u0430",20],[12,"\u0442\u044b\u0441\u044f\u0447 | \u0441\u0442 | \u0440\u0443\u0431\u043b\u0435\u0439 | \u0434\u043e | \u043d\u0430\u043b\u043e\u0436\u0435\u043d\u0438\u0435",20],[13,"\u043a\u0430\u043d\u0434\u0438\u0434\u0430\u0442\u043e\u0432 | \u043f\u0440\u043e\u0442\u0438\u0432 | \u0433\u043e\u043b\u043e\u0441\u043e\u0432 | \u0432\u0441\u0435\u0445 | \u0441\u043f\u0438\u0441\u043a\u043e\u0432",18],[14,"\u0443\u043f\u043a | \u0440\u0444 | \u0443\u043a | \u043f\u0440\u0438\u0441\u044f\u0436\u043d\u044b\u0445 | \u0437\u0430\u0441\u0435\u0434\u0430\u0 ...

# %% [markdown]
# ## Topics over Time
# Before we start with the Dynamic Topic Modeling step, it is important that you are satisfied with the topics that were created previously. We are going to be using those specific topics as a base for Dynamic Topic Modeling.
#
# Thus, this step will essentially show you how the topics that were defined previously have evolved over time.

# %% [markdown]
# There are a few important parameters that you should take note of, namely:
#
# * `docs`
#   * These are the tweets that we are using
# * `timestamps`
#   * The timestamp of each tweet/document
# * `global_tuning`
#   * Whether to average the topic representation of a topic at time *t* with its global topic representation
# * `evolution_tuning`
#   * Whether to average the topic representation of a topic at time *t* with the topic representation of that topic at time *t-1*
# * `nr_bins`
#   * The number of bins to put our timestamps into. It is computationally inefficient to extract the topics at thousands of different timestamps. Therefore, it is advised to keep this value below 20.

# %%
topics_over_time = topic_model.topics_over_time(docs=text, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 15it [00:14,  1.01it/s]

# %% [markdown]
# ## Visualize Topics over Time
# After having created our `topics_over_time`, we will have to visualize those topics as accessing them becomes a bit more difficult with the added temporal dimension.
#
# To do so, we are going to visualize the distribution of topics over time based on their frequency. Doing so allows us to see how the topics have evolved over time. Make sure to hover over any point to see how the topic representation at time *t* differs from the global topic representation.

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="550f6707-62a2-4e8d-b8c5-1c01f2475bca" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("550f6707-62a2-4e8d-b8c5-1c01f2475bca")) {                    Plotly.newPlot(                        "550f6707-62a2-4e8d-b8c5-1c01f2475bca",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u043f\u043e\u0432\u0435\u0440\u0435\u043d\u043d\u043e\u0433\u043e, \u043f\u0430\u0442\u0435\u043d\u0442\u043d\u043e\u0433\u043e, \u043f\u043e\u0432\u0435\u0440\u0435\u043d\u043d\u044b\u0445, \u043f\u0430\u0442\u0435\u043d\u0442\u043d\u044b\u0445, \u0438\u043d\u0442\u0435\u043b\u043b\u0435\u043a\u0442\u0443\u0430\u043b\u044c\u043d\u043e\u0439","<b>Topic 0</b><br>Words: \u043a\u0440\u0435\u0434\u0438\u0442\u043d\u043e\u0433\u043e, \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430, \u044d\u043d\u0435\u0440\u0433\u0435\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0439, \u044d\u0444\u0444\u0435\u043a\u0442\u0438\u0432\u043d\u043e\u0441\u0442\u0438, \u0432\u043e\u0437\u0434\u0443\u0448\u043d\u044b\u0435","<b>Topic 0</b><br>Words: \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0433\u043e, \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u044b\u0445, \u0442\u043e\u0432\u0430\u0440\u043e\u0432, \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0439, \u043b\u0435\u043a\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0433\u043e","<b>Topic 0</b><br>Words: \u043f\u043b\u0430\u0442\u0435\u0436\u043d\u043e\u0439, \u0440\u0430\u0434\u0438\u043e\u0430\u043a\u0442\u0438\u0432\u043d\u044b\u0445, \u043e\u0442\u0445\u043e\u0434\u043e\u0432, \u043e\u0441\u043c\u043e\u0442\u0440\u0430, \u0441\u0438\u0441\u0442\u0435\u043c\u044b","<b>Topic 0</b><br>Words: \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u043d\u0438\u044f, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u0443\u044e, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u044b\u0445, \u043e\u0431\u0443\u0447\u0430\u044e\u0449\u0438\u0445\u0441\u044f","<b>Topic 0</b><br>Words: \u043a\u043e\u043d\u0442\u0440\u0430\u043a\u0442\u0430, \u0437\u0430\u043a\u0443\u043f\u043e\u043a, \u0443\u0447\u0430\u0441\u0442\u0438\u0435, \u0437\u0430\u043a\u0443\u043f\u043a\u0438, \u0430\u0443\u043a\u0446\u0438\u043e\u043d\u0435","<b>Topic 0</b><br>Words: \u0441\u0442\u0440\u0430\u0442\u0435\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0433\u043e, \u043f\u043b\u0430\u043d\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f, \u0441\u043e\u0446\u0438\u0430\u043b\u044c\u043d\u043e, \u0440\u0430\u0437\u0432\u0438\u0442\u0438\u044f, \u044d\u043a\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u043e\u0433\u043e","<b>Topic 0</b><br>Words: \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u0438, \u0430\u0434\u043c\u0438\u043d\u0438\u0441\u0442\u0440\u0430\u0442\u0438\u0432\u043d\u043e\u0433\u043e, \u0441\u0443\u0434\u0430, \u0441\u0443\u0434, \u0432\u043b\u0430\u0434\u0438\u0432\u043e\u0441\u0442\u043e\u043a","<b>Topic 0</b><br>Words: \u0442\u043e\u0432\u0430\u0440\u0438\u0449\u0435\u0441\u0442\u0432\u0430, \u0441\u0430\u0434\u043e\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u043e\u0433\u043e\u0440\u043e\u0434\u043d\u0438\u0447\u0435\u0441\u0442\u0432\u0430, \u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u0430, \u0437\u0430\u0441\u0442\u0440\u043e\u0439\u0449\u0438\u043a\u0430","<b>Topic 0</b><br>Words: \u0443\u0433\u043e\u043b\u043e\u0432\u043d\u043e, \u0436\u0438\u0432\u043e\u0442\u043d\u044b\u0445, \u043e\u0431\u0449\u0435\u0441\u0442\u0432\u0430, \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u ...

# %% [markdown]
# Min_topic_size=5

# %%
from bertopic import BERTopic
topic_model_1 = BERTopic(min_topic_size=5, 
                       verbose=True, 
                       language='russian', 
                       top_n_words = 10,
                       n_gram_range=(5, 8),
                       vectorizer_model=vectorizer_model)

# %%
topics, _ = topic_model_1.fit_transform(text)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]
# 2022-12-16 16:59:32,691 - BERTopic - Transformed documents to Embeddings
# 2022-12-16 16:59:47,376 - BERTopic - Reduced dimensionality
# 2022-12-16 16:59:47,536 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model_1.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                               Name
# 0     -1    514                     -1_федерации_российской_или_ст
# 1      0     88           0_или_исполнительной_таможенного_товаров
# 2      1     57                      1_цифры_ст_цифрами_налогового
# 3      2     51  2_иностранного_государства_гражданства_подданства
# 4      3     50                3_диссертационного_строка_ст_строке
# 5      4     49                   4_кандидатов_ст_против_федерации
# 6      5     48               5_2020_коронавирусной_инфекции_новой
# 7      6     43                   6_цвета_кооператива_ордена_темно
# 8      7     42                        7_мвд_внутренних_дел_россии
# 9      8     39       8_области_волгоградской_коронавирусной_covid

# %%
topic_model_1.get_topic(4)
# Out:
# [('кандидатов', 0.01351672612629692),
#  ('ст', 0.011848234385103433),
#  ('против', 0.011532179549182921),
#  ('федерации', 0.010344315235922665),
#  ('тысяч', 0.010269488606727366),
#  ('дополнить', 0.010063451898509457),
#  ('российской', 0.009489200414166607),
#  ('следующего', 0.00887698515265226),
#  ('всех', 0.008633295504512658),
#  ('содержания', 0.008448573059016267)]

# %%
fig = topic_model_1.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d9fce2b1-05b9-4be2-8496-78684b21a862" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9fce2b1-05b9-4be2-8496-78684b21a862")) {                    Plotly.newPlot(                        "d9fce2b1-05b9-4be2-8496-78684b21a862",                        [{"customdata":[[0,"\u0438\u043b\u0438 | \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 | \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0433\u043e | \u0442\u043e\u0432\u0430\u0440\u043e\u0432 | \u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u043c",88],[1,"\u0446\u0438\u0444\u0440\u044b | \u0441\u0442 | \u0446\u0438\u0444\u0440\u0430\u043c\u0438 | \u043d\u0430\u043b\u043e\u0433\u043e\u0432\u043e\u0433\u043e | \u0441\u044b\u0440\u044c\u044f",57],[2,"\u0438\u043d\u043e\u0441\u0442\u0440\u0430\u043d\u043d\u043e\u0433\u043e | \u0433\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432\u0430 | \u0433\u0440\u0430\u0436\u0434\u0430\u043d\u0441\u0442\u0432\u0430 | \u043f\u043e\u0434\u0434\u0430\u043d\u0441\u0442\u0432\u0430 | \u043f\u043e\u0441\u0442\u043e\u044f\u043d\u043d\u043e\u0435",51],[3,"\u0434\u0438\u0441\u0441\u0435\u0440\u0442\u0430\u0446\u0438\u043e\u043d\u043d\u043e\u0433\u043e | \u0441\u0442\u0440\u043e\u043a\u0430 | \u0441\u0442 | \u0441\u0442\u0440\u043e\u043a\u0435 | \u043f\u0440\u0438",50],[4,"\u043a\u0430\u043d\u0434\u0438\u0434\u0430\u0442\u043e\u0432 | \u0441\u0442 | \u043f\u0440\u043e\u0442\u0438\u0432 | \u0444\u0435\u0434\u0435\u0440\u0430\u0446\u0438\u0438 | \u0442\u044b\u0441\u044f\u0447",49],[5,"2020 | \u043a\u043e\u0440\u043e\u043d\u0430\u0432\u0438\u0440\u0443\u0441\u043d\u043e\u0439 | \u0438\u043d\u0444\u0435\u043a\u0446\u0438\u0438 | \u043d\u043e\u0432\u043e\u0439 | covid",48],[6,"\u0446\u0432\u0435\u0442\u0430 | \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430 | \u043e\u0440\u0434\u0435\u043d\u0430 | \u0442\u0435\u043c\u043d\u043e | \u0441\u0438\u043d\u0435\u0433\u043e",43],[7,"\u043c\u0432\u0434 | \u0432\u043d\u0443\u0442\u0440\u0435\u043d\u043d\u0438\u0445 | \u0434\u0435\u043b | \u0440\u043e\u0441\u0441\u0438\u0438 | \u043f\u043e\u043b\u0438\u0446\u0438\u0438",42],[8,"\u043e\u0431\u043b\u0430\u0441\u0442\u0438 | \u0432\u043e\u043b\u0433\u043e\u0433\u0440\u0430\u0434\u0441\u043a\u043e\u0439 | \u043a\u043e\u0440\u043e\u043d\u0430\u0432\u0438\u0440\u0443\u0441\u043d\u043e\u0439 | covid | \u0438\u043d\u0444\u0435\u043a\u0446\u0438\u0438",39],[9,"\u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439 | \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u043e\u043d\u043d\u044b\u0445 | \u0441\u0432\u044f\u0437\u0438 | \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u044f | \u0434\u043e\u0431\u0440\u043e\u0432\u043e\u043b\u044c\u0447\u0435\u0441\u043a\u043e\u0439",32],[10,"\u043f\u0435\u043d\u0441\u0438\u0438 | \u0440\u0435\u043d\u043e\u0432\u0430\u0446\u0438\u0438 | \u0437\u0430\u043d\u044f\u0442\u043e\u0441\u0442\u0438 | \u0441\u0442 | \u0441\u0442\u0440\u0430\u0445\u043e\u0432\u043e\u0439",31],[11,"\u0440\u0444 | \u0433\u043a | \u0430\u043f\u043a | \u0441\u0442\u0430\u0442\u044c\u0438 | \u043a\u0430\u0441",31],[12,"\u0441\u0443\u0431\u0441\u0438\u0434\u0438\u0438 | \u043d\u0430\u0441\u0442\u043e\u044f\u0449\u0438\u0445 | \u043a\u0440\u0435\u0434\u0438\u0442\u0430\u043c | \u043f\u0440\u0430\u0432\u0438\u043b | \u0437\u0430\u0439\u043c\u0430\u043c",31],[13,"\u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u043d\u043e\u0433\u043e | \u0441\u0440\u0435\u0434\u0441\u0442\u0432\u0430 | \u043c\u0435\u0442\u0440\u043e\u043f\u043e\u043b\u0438\u0442\u0435\u043d\u0430 | \u0434\u0432\u0438\u0436\u0435\u043d\u0438\u044f | \u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u043d\u0 ...

# %%
topics_over_time = topic_model_1.topics_over_time(docs=text, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 15it [00:15,  1.04s/it]

# %%
topic_model_1.visualize_topics_over_time(topics_over_time, top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="64cb59a6-3fc4-45a9-aec0-5756bcf26421" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64cb59a6-3fc4-45a9-aec0-5756bcf26421")) {                    Plotly.newPlot(                        "64cb59a6-3fc4-45a9-aec0-5756bcf26421",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u043f\u043e\u0432\u0435\u0440\u0435\u043d\u043d\u043e\u0433\u043e, \u043f\u0430\u0442\u0435\u043d\u0442\u043d\u043e\u0433\u043e, \u043f\u043e\u0432\u0435\u0440\u0435\u043d\u043d\u044b\u0445, \u043f\u0430\u0442\u0435\u043d\u0442\u043d\u044b\u0445, \u0438\u043d\u0442\u0435\u043b\u043b\u0435\u043a\u0442\u0443\u0430\u043b\u044c\u043d\u043e\u0439","<b>Topic 0</b><br>Words: \u043a\u0440\u0435\u0434\u0438\u0442\u043d\u043e\u0433\u043e, \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432\u0430, \u044d\u043d\u0435\u0440\u0433\u0435\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0439, \u044d\u0444\u0444\u0435\u043a\u0442\u0438\u0432\u043d\u043e\u0441\u0442\u0438, \u0432\u043e\u0437\u0434\u0443\u0448\u043d\u044b\u0435","<b>Topic 0</b><br>Words: \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0433\u043e, \u0442\u043e\u0432\u0430\u0440\u043e\u0432, \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u044b\u0445, \u0442\u0430\u043c\u043e\u0436\u0435\u043d\u043d\u043e\u0439, \u043b\u0435\u043a\u0430\u0440\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0433\u043e","<b>Topic 0</b><br>Words: \u043f\u043b\u0430\u0442\u0435\u0436\u043d\u043e\u0439, \u0440\u0430\u0434\u0438\u043e\u0430\u043a\u0442\u0438\u0432\u043d\u044b\u0445, \u043e\u0442\u0445\u043e\u0434\u043e\u0432, \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u0441\u0438\u0441\u0442\u0435\u043c\u044b","<b>Topic 0</b><br>Words: \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u043d\u0438\u044f, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u0443\u044e, \u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u044b\u0445, \u043e\u0431\u0443\u0447\u0430\u044e\u0449\u0438\u0445\u0441\u044f","<b>Topic 0</b><br>Words: \u043a\u043e\u043d\u0442\u0440\u0430\u043a\u0442\u0430, \u0437\u0430\u043a\u0443\u043f\u043e\u043a, \u0443\u0447\u0430\u0441\u0442\u0438\u0435, \u0437\u0430\u043a\u0443\u043f\u043a\u0438, \u0430\u0443\u043a\u0446\u0438\u043e\u043d\u0435","<b>Topic 0</b><br>Words: \u0441\u0442\u0440\u0430\u0442\u0435\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0433\u043e, \u043f\u043b\u0430\u043d\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f, \u0441\u043e\u0446\u0438\u0430\u043b\u044c\u043d\u043e, \u0440\u0430\u0437\u0432\u0438\u0442\u0438\u044f, \u044d\u043a\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u043e\u0433\u043e","<b>Topic 0</b><br>Words: \u043d\u0435\u0434\u0432\u0438\u0436\u0438\u043c\u043e\u0441\u0442\u0438, \u0430\u0434\u043c\u0438\u043d\u0438\u0441\u0442\u0440\u0430\u0442\u0438\u0432\u043d\u043e\u0433\u043e, \u0441\u0443\u0434\u0430, \u0438\u043b\u0438, \u0441\u0443\u0434","<b>Topic 0</b><br>Words: \u0442\u043e\u0432\u0430\u0440\u0438\u0449\u0435\u0441\u0442\u0432\u0430, \u0441\u0430\u0434\u043e\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u043e\u0433\u043e\u0440\u043e\u0434\u043d\u0438\u0447\u0435\u0441\u0442\u0432\u0430, \u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u0430, \u0437\u0430\u0441\u0442\u0440\u043e\u0439\u0449\u0438\u043a\u0430","<b>Topic 0</b><br>Words: \u0443\u0433\u043e\u043b\u043e\u0432\u043d\u043e, \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439, \u043e\u0431\u0449\u0435\u0441\u0442\u0432\u0430, \u0436\u0438\u ...

# %% [markdown]
# min_topic_size=10
# n_gram_range 3-5
# top_n_words = 15

# %%
from bertopic import BERTopic
topic_model_10 = BERTopic(min_topic_size=10, 
                       verbose=True, 
                       language='russian', 
                       top_n_words = 15,
                       n_gram_range=(3, 5))

# %%
topics, _ = topic_model_10.fit_transform(text)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]
# 2022-12-16 17:01:26,206 - BERTopic - Transformed documents to Embeddings
# 2022-12-16 17:01:40,865 - BERTopic - Reduced dimensionality
# 2022-12-16 17:01:40,997 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model_10.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                               Name
# 0     -1    620  -1_субъекта российской федерации_законодательс...
# 1      0    107  0_на срок до_свободы на срок_свободы на срок д...
# 2      1     97  1_правительства российской федерации_правитель...
# 3      2     88  2_настоящего федерального закона_настоящим фед...
# 4      3     81  3_настоящего федерального закона_объектов инфо...
# 5      4     59  4_000 заменить цифрами_налогового кодекса росс...
# 6      5     54  5_социально экономического исключить_слово соц...
# 7      6     51  6_на постоянное проживание_на территории иност...
# 8      7     49  7_новой коронавирусной инфекции_коронавирусной...
# 9      8     48  8_юстиции российской федерации_на обучение по_...

# %%
topic_model_10.get_topic(4)
# Out:
# [('000 заменить цифрами', 0.005010126796833596),
#  ('налогового кодекса российской федерации', 0.0037725543488713446),
#  ('налогового кодекса российской', 0.003770116379238386),
#  ('кодекса российской федерации', 0.002933905272788006),
#  ('цифры 000 заменить цифрами', 0.0028173946231005715),
#  ('цифры 000 заменить', 0.0028173946231005715),
#  ('изложить следующей редакции', 0.0025671760202683057),
#  ('территории российской федерации', 0.002461150934119575),
#  ('второй налогового кодекса российской федерации', 0.002024877873032526),
#  ('части второй налогового', 0.002024877873032526),
#  ('части второй налогового кодекса российской', 0.002024877873032526),
#  ('части второй налогового кодекса', 0.002024877873032526),
#  ('второй налогового кодекса российской', 0.0020234149589717027),
#  ('второй налогового кодекса', 0.0020234149589717027),
#  ('пункта статьи 182 настоящего кодекса', 0.0019534408815686595)]

# %%
fig = topic_model_10.visualize_topics(); fig

# %%
topics_over_time = topic_model_10.topics_over_time(docs=text, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)

# %%
topic_model_1.visualize_topics_over_time(topics_over_time, top_n_topics=20)
